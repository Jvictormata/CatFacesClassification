# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from sklearn.model_selection import train_test_split
import time


from jax import grad,jit,random, jacfwd
import jax.numpy as jnp

# %matplotlib inline

# %%
lamb = 0.0001

# %% [markdown]
# # Loading Data

# %%
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            images.append(img.reshape(1,64*64))
    images = np.array(images)
    images = images.reshape(images.shape[0],64*64)/255
    return images

# %%
X_cats = load_images_from_folder("dataset_cats/cats/")
y_cats = np.ones((X_cats.shape[0],1))
X_noncats = load_images_from_folder("dataset_cats/non-cats/")
y_noncats = np.zeros((X_noncats.shape[0],1))

X_data = np.append(X_cats,X_noncats, axis=0)
X_data = np.append(np.ones((X_data.shape[0],1)),X_data,axis = 1)
y_data = np.append(y_cats,y_noncats, axis=0)


X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=9)

Xy_train = np.concatenate([X_train,y_train], axis=1)
Xy_test = np.concatenate([X_test,y_test], axis=1)

# %%
# Example of a picture
index = 0
plt.imshow(X_train[index,1:].reshape((64,64)),cmap="gray")
print ("y = " + str(y_train[index]))
# Out:
# y = [1.]

# %% [markdown]
# # Defining Functions

# %%
def sigmoid(z):
    s = 1/(1+np.exp(-z))    
    return s

# %%
def initialize_with_zeros(dim):
    w = np.zeros((dim,1))
    assert(w.shape == (dim,1))
    return w

# %%
def mini_batch(X_in,y_in,size,i):
    size = int(size)
    n = int(i%(X_in.shape[0]/size))
    return X_in[n*size:(n+1)*size], y_in[n*size:(n+1)*size]

# %%
def predict(w, X):
    m = X.shape[0]
    Y_prediction = np.zeros((m,1))
    
    A = sigmoid(X@w)
    
    Y_prediction = (A >= 0.5) * 1.0    
    return Y_prediction

# %%
def calc_accuracy(w,X,y):
    return 100 - np.mean(np.abs(predict(w,X) - y)) * 100

# %%
@jit
def sigmoid_jax(w,X):
    z = X@w
    s = 1/(1+jnp.exp(-z))    
    return s

# %%
def cost_function_jax(w,X_train,y_real,lamb=0):
    m = X_train.shape[1]
    y_predicted = np.array(sigmoid_jax(w,X_train))
    term1 = np.copy(y_predicted)
    term1[y_real == 0] = 1
    term2 = 1 - np.copy(y_predicted)
    term2[y_real == 1] = 1
    cost = np.sum(((- np.log(term1))*y_real + (-np.log(term2))*(1-y_real)))/m  + lamb*w.T@w
    return cost

# %%
@jit
def gradient_w_jax(w,X,y,lamb=0):
    lamb = 0.00001
    return X.T@(sigmoid_jax(w,X)-y)/(X.shape[1]) + 2*lamb*w

# %%
len(train_loader)
# Out:
# 10

# %% [markdown]
# # Optimization - Adam

# %%
def optimize_adam(w,X_train, y_train, learning_rate, beta1, beta2, num_iterations, lamb, print_cost = False):    
    costs = []
    acc = []
    
    eps=1e-8

    m = X_train.shape[1]
    size = 192
    
    init_time = time.time()
        
    for i in range(num_iterations):
        X_train_batch, y_train_batch = mini_batch(X_train,y_train,size,i)
        
        A = sigmoid(X_train_batch@w)
        grad_w = gradient_w_jax(w,X_train_batch,y_train_batch,lamb)#(X_train_batch.T@(A-y_train_batch))/size
        
        if i == 0:
            mw = grad_w
            vw = (grad_w**2).reshape(X_train.shape[1],1)
        else:
            mw = beta1*mw + (1-beta1)*grad_w
            vw = beta2*vw + (1-beta2)*((grad_w**2).reshape(X_train.shape[1],1))
        
        mw_hat = mw/(1-beta1**(i+1))
        vw_hat = vw/(1-beta2**(i+1))        
        
        alfa = learning_rate
        
        w = w - (alfa*mw_hat/(np.sqrt(vw_hat)+eps))
        
        if print_cost:
            A = sigmoid(X_train@w)
            #cost = cost_function_jax(w,X_train,y_train,lamb)
            cost = np.sum(((- np.log(A))*y_train + (-np.log(1-A))*(1-y_train)))/m
            costs.append(cost)
            acc.append(calc_accuracy(w,X_test,y_test))
            print ("Cost after iteration %i: %f" %(i, cost))
            
    elapsed = time.time() - init_time
    print("elapsed time: " + str(elapsed))
            
    return w,costs,acc

# %%
w = initialize_with_zeros(X_train.shape[1])
w_adam,costs_adam,acc_adam = optimize_adam(w, X_train, y_train, 0.005, 0.9, 0.999, int(201), lamb, True)
# Out:
# Cost after iteration 0: 0.304977
# Cost after iteration 1: 0.281219
# Cost after iteration 2: 0.284057
# Cost after iteration 3: 0.276070
# Cost after iteration 4: 0.298570
# Cost after iteration 5: 0.268877
# Cost after iteration 6: 0.281466
# Cost after iteration 7: 0.309899
# Cost after iteration 8: 0.275448
# Cost after iteration 9: 0.281729
# Cost after iteration 10: 0.307501
# Cost after iteration 11: 0.288422
# Cost after iteration 12: 0.266760
# Cost after iteration 13: 0.280871
# Cost after iteration 14: 0.280793
# Cost after iteration 15: 0.263043
# Cost after iteration 16: 0.261513
# Cost after iteration 17: 0.260285
# Cost after iteration 18: 0.255343
# Cost after iteration 19: 0.250131
# Cost after iteration 20: 0.247521
# Cost after iteration 21: 0.246183
# Cost after iteration 22: 0.243867
# Cost after iteration 23: 0.238158
# Cost after iteration 24: 0.241517
# Cost after iteration 25: 0.235598
# Cost after iteration 26: 0.230041
# Cost after iteration 27: 0.240555
# Cost after iteration 28: 0.232570
# Cost after iteration 29: 0.225769
# Cost after iteration 30: 0.238686
# Cost after iteration 31: 0.227694
# Cost after iteration 32: 0.223100
# Cost after iteration 33: 0.227714
# Cost after iteration 34: 0.218098
# Cost after iteration 35: 0.217857
# Cost after iteration 36: 0.220957
# Cost after iteration 37: 0.214465
# Cost after iteration 38: 0.217601
# Cost after iteration 39: 0.213091
# Cost after iteration 40: 0.214088
# Cost after iteration 41: 0.213005
# Cost after iteration 42: 0.211203
# Cost after iteration 43: 0.209977
# Cost after iteration 44: 0.208845
# Cost after iteration 45: 0.208070
# Cost after iteration 46: 0.206651
# Cost after iteration 47: 0.209562
# Cost after iteration 48: 0.206491
# Cost after iteration 49: 0.206017
# Cost after iteration 50: 0.210872
# Cost after iteration 51: 0.202985
# Cost after iteration 52: 0.209495
# Cost after iteration 53: 0.203753
# Cost after iteration 54: 0.202600
# Cost after iteration 55: 0.204608
# Cost after iteration 56: 0.199531
# Cost after iteration 57: 0.207954
# Cost after iteration 58: 0.203884
# Cost after iteration 147: 0.170602
# Cost after iteration 148: 0.173547
# Cost after iteration 149: 0.164442
# Cost after iteration 150: 0.180905
# Cost after iteration 151: 0.170319
# Cost after iteration 152: 0.169248
# Cost after iteration 153: 0.174283
# Cost after iteration 154: 0.162576
# Cost after iteration 155: 0.167986
# Cost after iteration 156: 0.164937
# Cost after iteration 157: 0.168079
# Cost after iteration 158: 0.171203
# Cost after iteration 159: 0.161990
# Cost after iteration 160: 0.178544
# Cost after iteration 161: 0.168260
# Cost after iteration 162: 0.166646
# Cost after iteration 163: 0.172274
# Cost after iteration 164: 0.160261
# Cost after iteration 165: 0.165576
# Cost after iteration 166: 0.162728
# Cost after iteration 167: 0.165595
# Cost after iteration 168: 0.168959
# Cost after iteration 169: 0.159664
# Cost after iteration 170: 0.176155
# Cost after iteration 171: 0.166326
# Cost after iteration 172: 0.164113
# Cost after iteration 173: 0.170307
# Cost after iteration 174: 0.158093
# Cost after iteration 175: 0.163235
# Cost after iteration 176: 0.160629
# Cost after iteration 177: 0.163205
# Cost after iteration 178: 0.166761
# Cost after iteration 179: 0.157474
# Cost after iteration 180: 0.173789
# Cost after iteration 181: 0.164459
# Cost after iteration 182: 0.161700
# Cost after iteration 183: 0.168377
# Cost after iteration 184: 0.156056
# Cost after iteration 185: 0.160992
# Cost after iteration 186: 0.158617
# Cost after iteration 187: 0.160945
# Cost after iteration 188: 0.164624
# Cost after iteration 189: 0.155416
# Cost after iteration 190: 0.171506
# Cost after iteration 191: 0.162658
# Cost after iteration 192: 0.159424
# Cost after iteration 193: 0.166512
# Cost after iteration 194: 0.154134
# Cost after iteration 195: 0.158862
# Cost after iteration 196: 0.156694
# Cost after iteration 197: 0.158814
# Cost after iteration 198: 0.162572
# Cost after iteration 199: 0.153474
# Cost after iteration 200: 0.169334
# elapsed time: 1.7718729972839355

# %% [markdown]
# # Results

# %%
ig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,5))

acc_adam_plot = [acc_adam[i] for i in range(1,len(acc_adam)) if i%10==0]


ax[0].plot(np.append(50,acc_adam_plot))



ax[1].plot(np.array(costs_adam).reshape(-1))


ax[0].set_xlabel("Epoch",fontsize=16)
ax[0].set_ylabel("Test accuracy",fontsize=16)
ax[1].set_ylabel("Training loss",fontsize=16)
ax[1].set_xlabel("Iteration",fontsize=16)

ax[0].tick_params(axis="x", labelsize=14) 
ax[0].tick_params(axis="y", labelsize=14) 
ax[1].tick_params(axis="x", labelsize=14) 
ax[1].tick_params(axis="y", labelsize=14) 

plt.savefig('logReg.pdf')

# %%
max(acc_adam_plot)
# Out:
# 78.95833333333333

# %%
acc_save = np.append(50,acc_adam_plot)/100
np.save("acc_logReg.npy", acc_save)
cost_save = np.array(costs_adam).reshape(-1)
np.save("cost_logReg.npy", cost_save)

# %%
init_time = time.time()
y_pred = sigmoid(X_test@w_adam)
elapsed = time.time() - init_time
print("elapsed time: " + str(elapsed))
# Out:
# elapsed time: 0.004225015640258789
